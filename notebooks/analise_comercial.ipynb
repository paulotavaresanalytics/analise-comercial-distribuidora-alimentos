# %% [markdown]
# # Análise Comercial — Distribuidora de Alimentos
#
# Notebook demonstrativo com dados fictícios para análise das métricas:
# - Meta vs Realizado
# - Curva ABC de Clientes
# - Churn
# - Ticket Médio
# - Previsão de Vendas
# - Mix de Produtos

# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path('..').resolve()
RAW_DIR = BASE_DIR / 'data' / 'raw'
PROCESSED_DIR = BASE_DIR / 'data' / 'processed'

clientes = pd.read_csv(RAW_DIR / 'clientes.csv')
produtos = pd.read_csv(RAW_DIR / 'produtos.csv')
pedidos = pd.read_csv(RAW_DIR / 'pedidos.csv', parse_dates=['data_pedido'])
metas = pd.read_csv(RAW_DIR / 'metas_mensais.csv')

clientes.head()
# Out:
#   cliente_id                cliente_nome               segmento estado  \
# 0      C0001  Cliente 001 Alimentos Ltda              Atacarejo     RJ
# 1      C0002  Cliente 002 Alimentos Ltda              Mercearia     RS
# 2      C0003  Cliente 003 Alimentos Ltda  Distribuidor Regional     ES
# 3      C0004  Cliente 004 Alimentos Ltda            Restaurante     GO
# 4      C0005  Cliente 005 Alimentos Ltda              Atacarejo     PE
#
#          regiao data_cadastro  status_ativo
# 0       Sudeste    2024-07-18          True
# 1           Sul    2024-09-18          True
# 2       Sudeste    2023-03-10          True
# 3  Centro-Oeste    2024-07-09          True
# 4      Nordeste    2023-04-04          True

# %%
meta_vs_realizado = pd.read_csv(PROCESSED_DIR / 'meta_vs_realizado.csv')
curva_abc = pd.read_csv(PROCESSED_DIR / 'curva_abc_clientes.csv')
churn = pd.read_csv(PROCESSED_DIR / 'churn_mensal.csv')
ticket = pd.read_csv(PROCESSED_DIR / 'ticket_medio.csv')
previsao = pd.read_csv(PROCESSED_DIR / 'previsao_vendas.csv')
mix = pd.read_csv(PROCESSED_DIR / 'mix_produtos.csv')

meta_vs_realizado.head()
# Out:
#    ano_mes  meta_vendas  realizado_vendas  atingimento_%  desvio_meta
# 0  2024-01   4512000.00         193751.38           4.29  -4318248.62
# 1  2024-02   4644062.61         167629.56           3.61  -4476433.05
# 2  2024-03   4777627.83         212102.43           4.44  -4565525.40
# 3  2024-04   4961822.61         187075.32           3.77  -4774747.29
# 4  2024-05   5049266.09         231950.99           4.59  -4817315.10

# %%
curva_abc.head(10)
# Out:
#   cliente_id  valor_total  participacao_%  participacao_acumulada_% classe_abc
# 0      C0062    191328.82        3.970376                  3.970376          A
# 1      C0142    121684.10        2.525138                  6.495514          A
# 2      C0022    112604.39        2.336719                  8.832233          A
# 3      C0088    109875.73        2.280095                 11.112329          A
# 4      C0157     96982.92        2.012549                 13.124878          A
# 5      C0101     78839.38        1.636042                 14.760920          A
# 6      C0056     74350.18        1.542884                 16.303804          A
# 7      C0096     68388.86        1.419177                 17.722981          A
# 8      C0031     68019.83        1.411519                 19.134500          A
# 9      C0011     66857.06        1.387390                 20.521890          A

# %%
churn.head()
# Out:
#    ano_mes  clientes_mes_anterior  clientes_perdidos  taxa_churn_%
# 0  2024-02                    143                 35         24.48
# 1  2024-03                    126                 28         22.22
# 2  2024-04                    137                 34         24.82
# 3  2024-05                    130                 33         25.38
# 4  2024-06                    136                 32         23.53

# %%
ticket.head()
# Out:
#    ano_mes  faturamento  pedidos  ticket_medio
# 0  2024-01    193751.38      312        621.00
# 1  2024-02    167629.56      269        623.16
# 2  2024-03    212102.43      318        666.99
# 3  2024-04    187075.32      267        700.66
# 4  2024-05    231950.99      323        718.11

# %%
previsao
# Out:
#    ano_mes  previsao_vendas
# 0  2026-01        191085.04
# 1  2026-02        190308.81
# 2  2026-03        189532.58

# %%
mix.head(15)
# Out:
#     categoria                 produto_nome  faturamento  volume  \
# 0       Arroz             Arroz Branco 5kg    812216.16   36164
# 1        Café            Café Torrado 500g    595769.67   35314
# 2       Arroz           Arroz Integral 1kg    353187.59   40048
# 3   Biscoitos  Biscoito Recheado Chocolate    307879.72   80951
# 4        Café            Café Premium 250g    290892.48   19978
# 5        Óleo       Óleo de Girassol 900ml    270457.84   27347
# 6      Feijão             Feijão Preto 1kg    270212.41   32505
# 7     Lácteos        Leite Condensado 395g    268368.52   39366
# 8      Açúcar          Açúcar Refinado 1kg    222663.24   42911
# 9        Óleo           Óleo de Soja 900ml    182576.16   24032
# 10    Lácteos        Leite UHT Integral 1L    169788.81   30227
# 11     Feijão           Feijão Carioca 1kg    168593.77   21262
# 12     Molhos       Extrato de Tomate 340g    168424.83   51097
# 13   Macarrão      Macarrão Espaguete 500g    160024.55   38078
# 14  Biscoitos       Biscoito Cream Cracker    130662.79   26710
#
#     participacao_faturamento_%
# 0                        16.85
# 1                        12.36
# 2                         7.33
# 3                         6.39
# 4                         6.04
# 5                         5.61
# 6                         5.61
# 7                         5.57
# 8                         4.62
# 9                         3.79
# 10                        3.52
# 11                        3.50
# 12                        3.50
# 13                        3.32
# 14                        2.71
# Bad pipe message: %s [b' q=0.9, image/avif, image/webp, image/apng, */*; q=0.8, application/signed-exchange; v=b3; q=0.7\r\nHost: loc', b'host:40189\r\nUser-Agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) C']
# Bad pipe message: %s [b'ome/146.0.0.0 Safari/537.36\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nAccept-Language: pt-BR, pt; q=0.']
# Bad pipe message: %s [b' en-US; q=0.8, en; q=0.7\r\nCache-Control: max-age=0\r\nRefe']
# Bad pipe message: %s [b'r: https://probable-cod-jjx9577x5v9xfqpqj.github.dev/\r\nX-Request-ID: 1e70a2a26447c215d259a940886172c8\r\nX-Real-IP:', b'0.241.0.36\r\nX-Forwarded-Port: 4', b'\r\nX-Forwarded-Scheme: https\r\nX-Original-URI: /\r\nX-S', b'eme: https\r\nsec-fetch-site: same-site\r\nsec-fetch-mode: navigate\r\nsec-fetch-dest: document\r\nsec-ch-']
# Bad pipe message: %s [b': "Chromium";v="146", "Not-A.Brand";v="24", "Google Chrome";v="146"\r\nsec-ch-ua-mobile: ?0\r\nsec-ch-ua-platform: "Linu', b'\r\npriority: u=0, i\r\nX-Forwarded-Proto: https\r\nX-Forwarded-Host: probable-cod-jjx9577x5v9xfqpqj-40189.app.github.dev\r\nX-']
